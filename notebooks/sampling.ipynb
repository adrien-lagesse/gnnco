# %%
import gnnco

# %%
graph = gnnco.random.erdos_renyi(1, 30, 0.5)[0]

# %%
sub_samples = gnnco.random.bfs_sub_sampling(graph.to_sparse(), 100, 15)

# %%
gnnco.visualization.plot_graph(sub_samples[0])

# %%
from torch_geometric.datasets import CoraFull

# %%
CORAFULL_ROOT = ".tmp/CoraFull"
dataset = CoraFull(root=CORAFULL_ROOT)
edge_index = dataset.edge_index
# Out:
# ...
# Processing...
# Done!

# %%
edge_index[0][edge_index[1] == 19378]
# Out:
# tensor([9259])

# %%
edge_index[1][edge_index[0] == 9259]
# Out:
# tensor([19378])

# %%
dataset
